# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.1/949.1 kB 14.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Checking CUDA availability
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Loading pretrained model

# %%
# Load YOLOv8 model (pretrained weights)
model = YOLO("yolo11s.pt")
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 38.8MB/s]

# %% [markdown]
# ## Pretrained accuracy on train and validation set

# %%
# checking metrics of pretrained model on train set
initial_train_metrics = model.val(data='/kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/data.yaml', split='train', device=device)
print(initial_train_metrics)
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 4.18MB/s]
# val: Scanning /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/train/labels... 10887 images, 7 backgrounds, 0 corrupt: 100%|██████████| 10887/10887 [00:31<00:00, 349.12it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 681/681 [01:34<00:00,  7.19it/s]
#                    all      10887      13300      0.104      0.203     0.0845      0.047
#                 person       2417       2641    0.00175      0.114    0.00104   0.000512
#                bicycle       8528      10659      0.205      0.292      0.168     0.0936
# ...

# %%
# checking metrics of pretrained model on validation set
initial_val_metrics = model.val(data='/kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/data.yaml', split='val', device=device)
print(initial_val_metrics)
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/valid/labels... 1296 images, 172 backgrounds, 0 corrupt: 100%|██████████| 1296/1296 [00:03<00:00, 400.95it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 81/81 [00:12<00:00,  6.60it/s]
#                    all       1296       1315     0.0585      0.241      0.045     0.0279
#                 person        362        396     0.0032      0.189    0.00196   0.000972
#                bicycle        778        919      0.114      0.292      0.088     0.0548
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...

# %% [markdown]
# ## Model Training

# %%
# Train the model using GPU if available
results = model.train(data="/kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/data.yaml", epochs=150, imgsz=640, amp=False, patience=10, augment=True, device=device)
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %% [markdown]
# ## Training and Validation Accuracy

# %%
metrics_train = model.val(device=device, split="train")
print(metrics_train)
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/train/labels... 10887 images, 7 backgrounds, 0 corrupt: 100%|██████████| 10887/10887 [00:15<00:00, 692.75it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 681/681 [02:44<00:00,  4.14it/s]
#                    all      10887      13300      0.947       0.93       0.97      0.764
#                    gun       2417       2641      0.932      0.908      0.954      0.695
#           heavy-weapon       8528      10659      0.963      0.951      0.985      0.832
# ...

# %%
# Validate the model
metrics_val = model.val(device=device, split="val")
print(metrics_val)
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/valid/labels... 1296 images, 172 backgrounds, 0 corrupt: 100%|██████████| 1296/1296 [00:02<00:00, 643.27it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapon-detection-16-without-knives/weapon-detection-16/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 81/81 [00:20<00:00,  3.98it/s]
#                    all       1296       1315      0.886      0.776      0.842      0.615
#                    gun        362        396       0.87      0.678      0.755      0.479
#           heavy-weapon        778        919      0.902      0.875      0.929      0.751
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...
