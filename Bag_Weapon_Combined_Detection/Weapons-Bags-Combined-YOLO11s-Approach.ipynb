# %%
# %%capture
pip install ultralytics

# %%
import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Checking CUDA availability
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Loading pretrained model

# %%
# Load YOLOv8 model (pretrained weights)
model = YOLO("yolo11s.pt")
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 206MB/s]

# %% [markdown]
# ## Pretrained accuracy on train and validation set

# %%
# checking metrics of pretrained model on train set
initial_train_metrics = model.val(data='/kaggle/input/weapons-bags-merged/weapons_bags_merged/data.yaml', split='train', device=device)
print(initial_train_metrics)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 20.3MB/s]
# val: Scanning /kaggle/input/weapons-bags-merged/weapons_bags_merged/train/labels... 34923 images, 65 backgrounds, 0 corrupt: 100%|██████████| 34965/34965 [01:44<00:00, 334.59it/s]
# val: WARNING ⚠️ /kaggle/input/weapons-bags-merged/weapons_bags_merged/train/images/aug_0_armas__169__jpg.rf.471978dd7e52f9f91c2a9a796a586b10.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-bags-merged/weapons_bags_merged/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2186/2186 [04:58<00:00,  7.33it/s]
#                    all      34965      41097     0.0362      0.185     0.0309      0.017
# ...

# %%
# checking metrics of pretrained model on validation set
initial_val_metrics = model.val(data='/kaggle/input/weapons-bags-merged/weapons_bags_merged/data.yaml', split='val', device=device)
print(initial_val_metrics)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapons-bags-merged/weapons_bags_merged/valid/labels... 1992 images, 177 backgrounds, 0 corrupt: 100%|██████████| 1997/1997 [00:06<00:00, 304.22it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-bags-merged/weapons_bags_merged/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:18<00:00,  6.84it/s]
#                    all       1997       2159     0.0393      0.192     0.0291     0.0181
#                 person        362        396     0.0027      0.189    0.00167   0.000828
#                bicycle        778        919      0.101      0.292     0.0776     0.0486
#                    car        696        844     0.0145      0.096    0.00821     0.0049
# ...

# %% [markdown]
# ## Model Training

# %%
# Train the model using GPU if available
results = model.train(data="/kaggle/input/weapons-bags-merged/weapons_bags_merged/data.yaml", epochs=150, imgsz=640, amp=False, patience=5, augment=True, device=device)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %% [markdown]
# ## Training and Validation Accuracy

# %%
metrics_train = model.val(device=device, split="train")
print(metrics_train)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 100 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /kaggle/input/weapons-bags-merged/weapons_bags_merged/train/labels... 34923 images, 65 backgrounds, 0 corrupt: 100%|██████████| 34965/34965 [01:02<00:00, 558.20it/s]
# val: WARNING ⚠️ /kaggle/input/weapons-bags-merged/weapons_bags_merged/train/images/aug_0_armas__169__jpg.rf.471978dd7e52f9f91c2a9a796a586b10.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-bags-merged/weapons_bags_merged/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2186/2186 [08:46<00:00,  4.16it/s]
#                    all      34965      41097      0.953      0.934      0.975      0.802
#                    gun      11810      12722      0.956      0.913      0.965        0.7
# ...

# %%
# Validate the model
metrics_val = model.val(device=device, split="val")
print(metrics_val)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapons-bags-merged/weapons_bags_merged/valid/labels... 1992 images, 177 backgrounds, 0 corrupt: 100%|██████████| 1997/1997 [00:03<00:00, 511.91it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-bags-merged/weapons_bags_merged/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:31<00:00,  4.00it/s]
#                    all       1997       2159      0.915      0.834       0.89      0.717
#                    gun        362        396      0.883      0.726      0.791      0.509
#           heavy-weapon        778        919      0.917      0.858      0.918      0.756
#                   bags        696        844      0.945      0.918      0.961      0.884
# ...

# %%
# evaluate the model on the test set
metrics_test = model.val(device=device, split='test')
print(metrics_test)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapons-bags-merged/weapons_bags_merged/test/labels... 348 images, 1 backgrounds, 0 corrupt: 100%|██████████| 349/349 [00:01<00:00, 185.73it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-bags-merged/weapons_bags_merged/test is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 22/22 [00:06<00:00,  3.35it/s]
#                    all        349        429      0.918      0.935      0.965      0.871
#                   bags        348        429      0.918      0.935      0.965      0.871
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...
