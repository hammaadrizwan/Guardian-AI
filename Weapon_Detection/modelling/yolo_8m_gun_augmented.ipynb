# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 16.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Checking CUDA availability
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Loading pretrained model

# %%
# Load YOLOv8 model (pretrained weights)
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 240MB/s]

# %% [markdown]
# ## Pretrained accuracy on train and validation set

# %%
# checking metrics of pretrained model on train set
initial_train_metrics = model.val(data='/kaggle/input/weapons-without-knife/weapon-detection-16/data.yaml', split='train', device=device)
print(initial_train_metrics)
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8m summary (fused): 92 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 17.9MB/s]
# val: Scanning /kaggle/input/weapons-without-knife/weapon-detection-16/train/labels... 20295 images, 22 backgrounds, 0 corrupt: 100%|██████████| 20295/20295 [01:57<00:00, 172.59it/s]
# val: WARNING ⚠️ /kaggle/input/weapons-without-knife/weapon-detection-16/train/images/aug_0_armas__169__jpg.rf.471978dd7e52f9f91c2a9a796a586b10.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-without-knife/weapon-detection-16/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1269/1269 [04:38<00:00,  4.55it/s]
#                    all      20295      23381     0.0541      0.212      0.047     0.0264
# ...

# %%
# checking metrics of pretrained model on validation set
initial_val_metrics = model.val(data='/kaggle/input/weapons-without-knife/weapon-detection-16/data.yaml', split='val', device=device)
print(initial_val_metrics)
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapons-without-knife/weapon-detection-16/valid/labels... 1296 images, 172 backgrounds, 0 corrupt: 100%|██████████| 1296/1296 [00:06<00:00, 213.33it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-without-knife/weapon-detection-16/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 81/81 [00:19<00:00,  4.25it/s]
#                    all       1296       1315     0.0807      0.233     0.0683     0.0441
#                 person        362        396    0.00336      0.167    0.00216    0.00116
#                bicycle        778        919      0.158        0.3      0.135     0.0869
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...

# %% [markdown]
# ## Model Training

# %%
# Train the model using GPU if available
results = model.train(data="/kaggle/input/weapons-without-knife/weapon-detection-16/data.yaml", epochs=150, imgsz=640, amp=False, patience=15, augment=True, device=device)
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %% [markdown]
# ## Training and Validation Accuracy

# %%
metrics_train = model.val(device=device, split="train")
print(metrics_train)
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /kaggle/input/weapons-without-knife/weapon-detection-16/train/labels... 20295 images, 22 backgrounds, 0 corrupt: 100%|██████████| 20295/20295 [00:33<00:00, 599.03it/s]
# val: WARNING ⚠️ /kaggle/input/weapons-without-knife/weapon-detection-16/train/images/aug_0_armas__169__jpg.rf.471978dd7e52f9f91c2a9a796a586b10.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-without-knife/weapon-detection-16/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1269/1269 [09:18<00:00,  2.27it/s]
#                    all      20295      23381      0.968      0.965      0.988      0.808
#                    gun      11810      12722      0.974      0.972      0.989      0.768
# ...

# %%
# Validate the model
metrics_val = model.val(device=device, split="val")
print(metrics_val)
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# val: Scanning /kaggle/input/weapons-without-knife/weapon-detection-16/valid/labels... 1296 images, 172 backgrounds, 0 corrupt: 100%|██████████| 1296/1296 [00:02<00:00, 582.66it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapons-without-knife/weapon-detection-16/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 81/81 [00:36<00:00,  2.22it/s]
#                    all       1296       1315      0.885      0.801       0.85       0.63
#                    gun        362        396      0.874       0.72      0.773      0.499
#           heavy-weapon        778        919      0.896      0.882      0.926      0.762
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...
